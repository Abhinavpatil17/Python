# %% [markdown]
# # HOTEL BOOKING CANCELLATION DATA ANALYSIS PROJECT

# %% [markdown]
# ### 1. IMPORTING LIBERARIES :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. LOADING THE DATSET :

# %%
df = pd.read_csv('hotel_bookings 2.csv')

# %% [markdown]
# ### 3. EXPLORATORY DATA ANALYSIS AND DATA CLEANING :

# %%
df.head() # top 5 rows of the data set
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail() # can see last part of the data set
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.tail(10) # last 10 rows
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
# How many number of rows and column are used in the data set ?

df.shape
# Out:
# (119390, 32)

# %%
# What are the columns in the data set

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# What are the data types in the data set

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Sab ka data type dekhne ne shi lg rha hai but 1 column hai "reservation_status_date" yeh object form me h  
# reservation_status_date vale column pe hi analysis perform krna hai 
# Isliyw hme pehle ise "date time me change krna hoga" 

# Sbse pehle agr aap koi data set use krre ho to usme dekho ki ko date vala column to ni hai
# Or agr vo date column jaruri hai to use date time me change kr lo

# %%
# Changing the date column into date-time :

df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
# Rechecking :

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Object data type = Catagorical columns
# Kis Catagorical columns me kitni unique values hai ya kitni categories hai hm vo bhi dekh skte hai

df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# Now see what are these categories in the object column 
# No. pta chl gya bai but konsi values bhi aa rhi hai vo ab hm dekhenege 
# Hme 1 loop chlana pdega jo objecty type k hai unke liye

for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)                # Sbhi columns ko output me acche se seperate kr dega pehle output bohot gich pich tha
    
# Filter krre hai dataframe ko us column ke sath
# Phir unique function ko pass krre hai
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
# Check null values 

df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Agent or company vale column ko hm remove kr denge
# Beacuse
# Agent vale column ki hmko jarurat nhi hai
# or 
# Company vale column ka data itna jyada hai ki hm use handle nhi kr skte

# Country or childern ka data bohot km hai to unko drop bhi kiya to bhi chlega

df.drop(['company' , 'agent'],axis = 1,inplace = True)
#columns_to_drop = ['agent' , 'company']
#df = df.drop(columns = columns_to_drop)

# If koi row or column remove krna hai to df.drop use hoga 
# Koi column remove krna hia to aapko axis = 1 dena pdega 
# Data framee me koi cganges krne hai to inplace = True as a parameter pass krna pdega
# Jitne bhi column remove krne hai uske list me dal skte hai vo remove ho jayenge

# --------------------------------------------------------------------------------------------------------

# FOR REMOVING ROWS WITH THE MISSING VALUES:
df.dropna(inplace = True)

# %%
# Again check for the missing values

df.isnull().sum()

# Null values sare columns me se ht chuki hai
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# Let's see tthe SUMMARY STATISTICS of the numerical column

df.describe()

# Yaha pr bohot jagah outliers hai..jese ki babies me 10 lekin koi bbi aaj k time m 10 babies nhi leke aata to ese hi adults me bbi outliers present hai
# But hm unko remove nhi krenge kyuki hypothesis me hmne assume kiya tha ki koi outliers nhi hai
# lekin "adr" (it is a column which shows price) me 1 jagah pr -ve me value hai or 1 jagah bohot high value hai jo ki bohot jyada bda outlier ho jayga to need to fix it if you want to amke more accurate analysis
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# There is only 1 outlier which is above 5000 and other than that all the outliers are below 1000
# Out:
# <Axes: >

# %%
# Let's remove the values from "adr" column because it shows tthe price

df = df[df['adr']<5000]
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# ### We have cleaned our dataset

# %% [markdown]
# ### -----------------------------------------------

# %% [markdown]
# ### 4. DATA ANALYSIS AND VISUALIZATIONS :

# %% [markdown]
# #### ANALYZE THE CLEANED DATASET :

# %% [markdown]
# **- 1ST ANALYSIS :** Dataset m kitne reservation ese hai jo cancel ho chuke hai or nhi cancel hue hai...we need to find out the percentage of that.

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize = 'True') # --> Normalize %ge k form me dega
cancelled_perc
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
# 200 or 0.628653%ge is not cancelled
# and
# 17 or 0.371347 reservations are cancelled which is half of the reservayions and 
# that's a huge amount so lets visualuze it :

# %%
plt.figure(figsize = (5,4))
plt.title('Reservation Status Count')
plt.bar(['Not Canceled' , 'Canceled'] , df['is_canceled'].value_counts(), edgecolor = 'k' , width = 0.7)
plt.show()


# Canceled ratio is more than half
# So its a major issue for the hotels

# %% [markdown]
# **- 2nd ANALYSIS :** Cancelled or not cancelled ka count / percentage to mil gya hai but ab dekhenge ki depending upon the hotels kiska cancelation rate jyada hai.

# %%
# First we will find for depending on the hotels
# For that we will use count plot

# %%
plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = 'hotel' , hue = 'is_canceled' , data = df , palette='Blues')
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status in different hotels' , size = 20)
plt.xlabel('Hotel')
plt.ylabel('Number of reservations')
plt.legend(['Not canceled' , 'Canceled'])
plt.show()


# Here we can see in below graph :
# Dono jo hotel hai unke top me bohot jyada difference hai
# In RESORT HOTEL : Cancelation km hote hai
# IN CITY HOTEL : Cancelation bohot jyada hai ==> Reservations km hai pr cancelation bohot jyada hai
# RESORT HOTEL ME ==> 'adr' is the most important case of thr canceelation of reservations
# CITY HOTEL ME ==> May be the case of maintainance or other facilities may be the reason of the cancelation.

# %% [markdown]
# ### Findings :
# #### 1. City hotels has more bookings and cancellations that resort type, reson may be resort hotel are more expensive.
# #### 2. City hotels needs to be focused more seeing the cancellations ratio, may be in maintanance , facilities, etc.

# %%
# Value ka count to pta chl gya but
# Percentage for Canceled & not canceled ke liye age dekhna hai RESORT HOTEL ka then :
# Sbse pehle data ko filter krenge : Resort hotel pe

resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)


# Below we can see:
# 28% reservations cancel ho rhe hai 
# But 72% not canceled hai
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
# Now lets see the same thing for the CITY HOTEL :

city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)


# Below we can see:
# 58% not canceled hai
# But 42% jo hai vo canceled hai ==> Jo ki 1 bohot bda number hai cancelation of reservation ke liye
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %% [markdown]
# **- 3rd ANALYSIS :** Kya price ka koi affect hai dono hotel ki cancelation me ?

# %%
# GROUP BT FUNCTION ka use krenge Group krne k liye on the 'reservation_status_date'
# Kyuki 1 hi din k bohot sare records hai
# To 1 din ke AVERAGE DAILY RATE ka mean value lenge

resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
# - Now we will create a visualization for the AVERAGE DAILY RATE in both city and resort hotels
# Hmne hypothesis me esa dekha tha ki jo RESORT HOTEL hai usme cancelation ke chances PRICE k vjh se hai
# To use chiz ko check krenge

plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City & Resort Hotel (ADR)' , fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# X value will be the Index (Index is reservation_status_date)
# Y will be the AVERAGE DAILY RATE




# ####################################################
# City hotel ki lines mid me hai ==> What does that mean ?? ==> 
# Or kuch spikes bhi hai ==> WHY? ==> Spikes is for weekends...weekends pe dono hotels ka price increase ho jata hai.
# City hotel ka price as compared to resort hotel km hai.
# Hypothesis is proved ==> City hotel price < resort hotel price

# %% [markdown]
# ### Findings :
# 1. City hotel is in mid (ADR) , some spikes may be due to weekends,holidays
# 2. City hotel price < resort hotel price
#
# HENCE, HYPOTHESIS IS PROVED !!

# %% [markdown]
# **- 4th ANALYSIS :** Kis month me sbse jyada reservations hai or kisme sb se jyada cancelations .

# %%
# We'll use bar chart to see the cancelations and not cancelations in a month by grouping then we can compare 
# We want x axis pe month ==> for that ==> hmare pass month ka koi column nhi hai reeservation_status_date ke liye 
# Hmne use datetime m convert kiya tha ab usme month krke 1 date extend krna hai

df['month'] = df['reservation_status_date'].dt.month  # ==> Sbse pehle month kkrke 1 column add kiya....jitni bhi date hai uske month isme return ho jayenge.
plt.figure(figsize = (16,8))
ax1 = sns.countplot(x = 'month' , hue = 'is_canceled' , data = df)
legend_labels,_ = ax1. get_legend_handles_labels()
ax1.legend(bbox_to_anchor = (1,1))
plt.title('Reservation Status Per Month' , size = 20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not canceled' , 'canceled'])
plt.show()


# x-axis me sare month k number h 1-12
# January me sbse jyada cancelations hue hai
# Sbse lowest hue hai Auguest me
# Analysis says that :
# Jb cancelations sbse km hai ===> tb hmare reservations sbse jyada hai
# Or jb cancelations sbse jyada hai ===> tb hmare reservation k hai
# Mtlb === > ?????????????
# CASE - 1 : Auguest me hotels k price km ho skte hai is vajah se jagah nhi mili ==> long waiting list ==> RESERVATION CANCELED
# OR
# CASE - 2 : Ya to price bohot jyada the to logo ne bookings cancel krva di

# %% [markdown]
# ### Findings :
# 1. Jan has more cancelations
# 2. Lowest cancelations in auguest
# 3. Auguest has most reservations
# 4. December Jan has least reservations.

# %% [markdown]
# ### Bit Confusing !
# Aug has least cancelations and most reservations , may be the prices are low in Aug so more reservations , or maybe the prices were too high , that people preferred cancelations.

# %% [markdown]
# ### Now lets plot the AVERAGE DAILY RATE for each month :
# - Ab visualization hm sirf CANCELED DATA k liye hi krenge
# - Because we want to check ==> ki price ka cancelation rate p koi affect hai ya nhi.

# %%
plt.figure(figsize = (15,8))
plt.title('ADR per month' , fontsize = 30)

df_filtered = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()
sns.barplot(x = 'month' , y='adr' , data = df_filtered)

plt.show()




# Aug me ADR(price) sbse km hai ==> sbse km cancelations
# Jan me ADR(price) sbse highest hai ==> sbse jyada cancelations
# Yeh hypothesis prove krta hai ki ==> Price = high ==> cancelation ==> high
# Price = low ==> cancelation ==> low

# %% [markdown]
# ### Findings :
# - ADR in Aug is lowest
# - ADR in Jan is highest
#
# #### Hence proved our hypothesis that, when higher prices the cancelations will be more

# %% [markdown]
# **- 4th ANALYSIS :** Countries k basis p kitna cancelation hai ==> Kis country me kitna cancelation hai. (TOP 10 COUNTRIES PE HI ANALYSIS KRENGE)

# %%
cancelled_data = df[df['is_canceled'] == 1]          # filtered data that is canceled
top_10_country = cancelled_data['country'].value_counts()[:10]      # creating a series from the canceled data
# Value_counts ==> kitni bar vo value column m aa rhi h

# %%
top_10_country
# Out:
# country
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country, autopct = '%.2f',labels = top_10_country.index) # '%.2f' ==> 2 decimals tk value dikhana
plt.show()


# PRT ==> Portugal country me sbse jyada cancelations hai ==> baki sb me km hai

# %% [markdown]
# ### Findings :
# In portugal country , increace the facalities and decrease the prices , hold promotional campaigns , give discounts , advertizements , marketing

# %% [markdown]
# **- 5th ANALYSIS :** Let's see the clients ,that where they are coming from ==> ONLINE TRAVEL AGENTS OR OFFLINE TRAVEL AGENTS.

# %% [markdown]
# Now lets assume that the most of the coustomers/ clients are coming through offline agents , like see it is true?

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)  # For percentage
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %% [markdown]
# ### Findings :
# - So we see that almots half of the costumers are coming through online agents
# - Thus proving our hypothesis wrong.

# %% [markdown]
# #### Yhi percentage jo cancel ho gya usme kitna hai vo dekhenge?

# %%
cancelled_data['market_segment'].value_counts(normalize=True)

# Cancelation bbi sbse jyada online me hi hai
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %% [markdown]
# ### Findings :
# - Almost 47% customers coming through online agents cancel their booking, this may be due to reasons like, the online picture was very good
# - and when the customer visited it may not be up to the mark due to lack of facilities, spaces,etc
# - so may be the hotels can portray the real  picture on online ads to avoid this.

# %% [markdown]
# **- 6th ANALYSIS :** Check prices of canceled bookings, are high ?

# %% [markdown]
# Price kiski high hai ?? cancelation valo ki ya non cancelation ki

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

plt.figure(figsize = (20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label = 'not canceled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label = 'canceled')
plt.legend
plt.show()


# data jyada hai isliye esa graph hai

# %% [markdown]
# ### Findings :
# - Now ths may be due to inconsistent data
# - So lets take only data of 2016and 2017 till sept

# %%
# 2015 se 2018 tkka data hmne yaha p filter kr liyA HAI dono fata frame k liye ==> cancelled or non canceled k liye bhi

cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date'] > '2016')&(cancelled_df_adr['reservation_status_date']<'2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016')&(not_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize = (20,6))
plt.title('Average Daily Rate', fontsize = 30)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'],label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'],label = 'not cancelled')
plt.legend(fontsize = 20)
plt.show()


# 2016 se last tk me plot

# %% [markdown]
# ### Findings :
# - We see that the cancelled line (orange) is more than the not canceled one
# - it proves that the prices have effect on cancelations.

# %% [markdown]
# ## Therefore, ADR is the most influencing factor on the cancelations rate.
